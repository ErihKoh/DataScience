# %% [markdown]
# Task1

# %%
import pandas as pd

my_table = pd.read_csv("2017_jun_final.csv")
my_table.set_index('N', inplace=True)


my_table.head()
# Out:
#                   Должность Язык.программирования Специализация  \
# N
# 1        Junior QA engineer                   NaN     Manual QA
# 2        Junior QA engineer                   NaN     Manual QA
# 3         Software Engineer               C#/.NET           NaN
# 4         Software Engineer            JavaScript           NaN
# 5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# N
# 1               0.5                          0.5               400
# 2  меньше 3 месяцев             меньше 3 месяцев               430
# 3                 4                            1              2500
# 4                 5                            4              2000
# 5    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# N
# 1                                 0  Харьков       до 10 человек
# 2                               130  Харьков  свыше 1000 человек
# 3                               800     Киев     до 1000 человек
# 4                               400   Одесса      до 200 человек
# 5                               500   Другой       до 10 человек
#
#      Тип.компании  ... Еще.студент  Уровень.английского  \
# N                  ...
# 1  Аутсорсинговая  ...        True        ниже среднего
# 2  Аутсорсинговая  ...        True        выше среднего
# 3  Аутсорсинговая  ...       False              средний
# 4     Продуктовая  ...       False        ниже среднего
# 5     Продуктовая  ...       False              средний
#
#                      Предметная.область      Дата.заполнения  \
# N
# 1                         iOS,eCommerce  12/06/2017 12:38:08
# 2                        Веб-разработка  12/06/2017 12:42:51
# 3  Веб-разработка,Корпоративные системы  12/06/2017 13:02:47
# 4   Desktop Applications,Веб-разработка  12/06/2017 13:03:01
# 5   Desktop Applications,Веб-разработка  12/06/2017 13:03:47
#
#                                           User.Agent   exp current_job_exp  \
# N
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5             0.5
# 2  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0             0.0
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0             1.0
# 4  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0             4.0
# 5  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0             0.5
#
#   salary Валюта  cls
# N
# 1    400    NaN   QA
# 2    430    NaN   QA
# 3   2500    NaN  DEV
# 4   2000    NaN  DEV
# 5   4500    NaN  DEV
#
# [5 rows x 24 columns]

# %% [markdown]
# Task2

# %%
print(f"кол-во столбцов :  {my_table.shape[1]}")
print(f"кол-во строк:  {my_table.shape[0]}")
# Out:
# кол-во столбцов :  25
# кол-во строк:  8704

# %% [markdown]
# Task3

# %%
my_table.dtypes
# Out:
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %% [markdown]
# Task4

# %%
my_table.isnull().sum()
# Out:
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64

# %% [markdown]
# Task5

# %%
lang = my_table["Язык.программирования"]
table_without_nan = my_table.dropna(axis=1)
result_table = pd.concat([table_without_nan, lang], axis=1)
result_table
# Out:
#                      Должность Общий.опыт.работы Опыт.работы.на.текущем.месте  \
# N
# 1           Junior QA engineer               0.5                          0.5
# 2           Junior QA engineer  меньше 3 месяцев             меньше 3 месяцев
# 3            Software Engineer                 4                            1
# 4            Software Engineer                 5                            4
# 5     Senior Software Engineer    10 и более лет                          0.5
# ...                        ...               ...                          ...
# 8700               QA engineer                 1             меньше 3 месяцев
# 8701                 Marketing               0.5                          0.5
# 8702  Junior Software Engineer                 1                          0.5
# 8703                 Team lead                 6                            4
# 8704  Senior Software Engineer                 7                            2
#
#       Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев    Город  \
# N
# 1                  400                                 0  Харьков
# 2                  430                               130  Харьков
# 3                 2500                               800     Киев
# 4                 2000                               400   Одесса
# 5                 4500                               500   Другой
# ...                ...                               ...      ...
# 8700               700                               700   Одесса
# 8701               400                               120     Киев
# 8702               800                               500    Львов
# 8703              2600                                 0    Днепр
# 8704              5000                               800   Одесса
#
#          Размер.компании     Тип.компании      Пол  Возраст  \
# N
# 1          до 10 человек   Аутсорсинговая  женский       20
# 2     свыше 1000 человек   Аутсорсинговая  женский       21
# 3        до 1000 человек   Аутсорсинговая  мужской       26
# 4         до 200 человек      Продуктовая  мужской       30
# 5          до 10 человек      Продуктовая  мужской       30
# ...                  ...              ...      ...      ...
# 8700       до 50 человек   Аутсорсинговая  мужской       23
# 8701       до 50 человек      Продуктовая  женский       22
# 8702       до 10 человек  Аутстаффинговая  мужской       30
# 8703  свыше 1000 человек   Аутсорсинговая  мужской       34
# 8704     до 1000 человек      Продуктовая  мужской       28
#
#                Образование  Еще.студент Уровень.английского  \
# N
# 1     Незаконченное высшее         True       ниже среднего
# 2     Незаконченное высшее         True       выше среднего
# 3                   Высшее        False             средний
# 4                  Среднее        False       ниже среднего
# 5       Техникум / Колледж        False             средний
# ...                    ...          ...                 ...
# 8700                Высшее        False             средний
# 8701                Высшее        False       ниже среднего
# 8702  Незаконченное высшее        False       выше среднего
# 8703                Высшее        False         продвинутый
# 8704                Высшее        False       выше среднего
#
#           Дата.заполнения                                         User.Agent  \
# N
# 1     12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2     12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 3     12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4     12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 5     12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# ...                   ...                                                ...
# 8700  12/07/2017 15:45:24  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8701  12/07/2017 17:00:06  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8702  12/07/2017 17:32:26  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8703  12/07/2017 18:14:59  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 8704  12/07/2017 21:28:57  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
#
#        exp  current_job_exp  salary Язык.программирования
# N
# 1      0.5              0.5     400                   NaN
# 2      0.0              0.0     430                   NaN
# 3      4.0              1.0    2500               C#/.NET
# 4      5.0              4.0    2000            JavaScript
# 5     10.0              0.5    4500            JavaScript
# ...    ...              ...     ...                   ...
# 8700   1.0              0.0     700                   NaN
# 8701   0.5              0.5     400                   NaN
# 8702   1.0              0.5     800            Ruby/Rails
# 8703   6.0              4.0    2600                   NaN
# 8704   7.0              2.0    5000                  Java
#
# [8704 rows x 19 columns]

# %% [markdown]
# Task6

# %%
result_table.isnull().sum()
# Out:
# Должность                              0
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Язык.программирования               3850
# dtype: int64

# %% [markdown]
# Task7

# %%
result_dropna = result_table.dropna()
result_dropna
# Out:
#                      Должность Общий.опыт.работы Опыт.работы.на.текущем.месте  \
# N
# 3            Software Engineer                 4                            1
# 4            Software Engineer                 5                            4
# 5     Senior Software Engineer    10 и более лет                          0.5
# 7     Junior Software Engineer                 1             меньше 3 месяцев
# 8     Senior Software Engineer                 6                            1
# ...                        ...               ...                          ...
# 8693         Software Engineer                 5                            1
# 8695  Junior Software Engineer                 1                            1
# 8696         Software Engineer                 1                          0.5
# 8702  Junior Software Engineer                 1                          0.5
# 8704  Senior Software Engineer                 7                            2
#
#       Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев        Город  \
# N
# 3                 2500                               800         Киев
# 4                 2000                               400       Одесса
# 5                 4500                               500       Другой
# 7                  600                               100  Хмельницкий
# 8                 3300                               500         Киев
# ...                ...                               ...          ...
# 8693              3500                               650     Удаленно
# 8695               550                               550      Харьков
# 8696              1500                              1000         Киев
# 8702               800                               500        Львов
# 8704              5000                               800       Одесса
#
#       Размер.компании     Тип.компании      Пол  Возраст  \
# N
# 3     до 1000 человек   Аутсорсинговая  мужской       26
# 4      до 200 человек      Продуктовая  мужской       30
# 5       до 10 человек      Продуктовая  мужской       30
# 7       до 50 человек   Аутсорсинговая  мужской       23
# 8       до 10 человек      Продуктовая  мужской       28
# ...               ...              ...      ...      ...
# 8693   до 200 человек   Аутсорсинговая  женский       28
# 8695   до 200 человек   Аутсорсинговая  мужской       23
# 8696    до 10 человек          Стартап  мужской       29
# 8702    до 10 человек  Аутстаффинговая  мужской       30
# 8704  до 1000 человек      Продуктовая  мужской       28
#
#                Образование  Еще.студент Уровень.английского  \
# N
# 3                   Высшее        False             средний
# 4                  Среднее        False       ниже среднего
# 5       Техникум / Колледж        False             средний
# 7                   Высшее        False       ниже среднего
# 8                   Высшее        False       выше среднего
# ...                    ...          ...                 ...
# 8693                Высшее        False             средний
# 8695                Высшее        False       ниже среднего
# 8696                Высшее        False             средний
# 8702  Незаконченное высшее        False       выше среднего
# 8704                Высшее        False       выше среднего
#
#           Дата.заполнения                                         User.Agent  \
# N
# 3     12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4     12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 5     12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# 7     12/06/2017 13:04:26  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8     12/06/2017 13:04:27  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....
# ...                   ...                                                ...
# 8693  12/07/2017 13:26:49  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
# 8695  12/07/2017 14:14:33  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:54.0) ...
# 8696  12/07/2017 14:39:21  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8702  12/07/2017 17:32:26  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8704  12/07/2017 21:28:57  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...
#
#        exp  current_job_exp  salary Язык.программирования
# N
# 3      4.0              1.0    2500               C#/.NET
# 4      5.0              4.0    2000            JavaScript
# 5     10.0              0.5    4500            JavaScript
# 7      1.0              0.0     600               C#/.NET
# 8      6.0              1.0    3300                   C++
# ...    ...              ...     ...                   ...
# 8693   5.0              1.0    3500                  Java
# 8695   1.0              1.0     550               C#/.NET
# 8696   1.0              0.5    1500                Python
# 8702   1.0              0.5     800            Ruby/Rails
# 8704   7.0              2.0    5000                  Java
#
# [4854 rows x 19 columns]

# %% [markdown]
# Task8

# %%
print(f"кол-во столбцов :  {result_dropna.shape[1]}")
print(f"кол-во строк:  {result_dropna.shape[0]}")
# Out:
# кол-во столбцов :  20
# кол-во строк:  4854

# %% [markdown]
# Task9

# %%
python_data = result_dropna.loc[result_dropna["Язык.программирования"].isin(["Python"])]
python_data
# Out:
#                      Должность Общий.опыт.работы Опыт.работы.на.текущем.месте  \
# N
# 13           Software Engineer                 1             меньше 3 месяцев
# 69           Software Engineer               1.5                          0.5
# 88    Junior Software Engineer               0.5                          0.5
# 115   Junior Software Engineer               1.5                          0.5
# 144   Junior Software Engineer                 1                            1
# ...                        ...               ...                          ...
# 8547         Software Engineer                 5                            1
# 8626         Software Engineer                 4                            1
# 8636  Senior Software Engineer    10 и более лет             меньше 3 месяцев
# 8674  Junior Software Engineer               0.5                          0.5
# 8696         Software Engineer                 1                          0.5
#
#       Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев      Город  \
# N
# 13                 800                               200       Киев
# 69                 900                               900       Киев
# 88                 600                                 0       Киев
# 115                685                               250       Киев
# 144                750                               250       Киев
# ...                ...                               ...        ...
# 8547              2000                               800  Запорожье
# 8626              1750                                 0       Киев
# 8636              4000                              1300   Удаленно
# 8674               350                                50       Киев
# 8696              1500                              1000       Киев
#
#          Размер.компании    Тип.компании      Пол  Возраст  \
# N
# 13         до 50 человек  Аутсорсинговая  мужской       26
# 69         до 10 человек         Стартап  мужской       21
# 88         до 10 человек  Аутсорсинговая  мужской       19
# 115      до 1000 человек  Аутсорсинговая  мужской       21
# 144        до 10 человек  Аутсорсинговая  мужской       21
# ...                  ...             ...      ...      ...
# 8547       до 50 человек  Аутсорсинговая  мужской       22
# 8626  свыше 1000 человек  Аутсорсинговая  мужской       28
# 8636       до 10 человек         Стартап  мужской       33
# 8674       до 50 человек  Аутсорсинговая  мужской       22
# 8696       до 10 человек         Стартап  мужской       29
#
#                Образование  Еще.студент Уровень.английского  \
# N
# 13                  Высшее        False       ниже среднего
# 69    Незаконченное высшее         True       выше среднего
# 88    Незаконченное высшее         True       выше среднего
# 115   Незаконченное высшее        False             средний
# 144   Незаконченное высшее         True       выше среднего
# ...                    ...          ...                 ...
# 8547  Незаконченное высшее        False             средний
# 8626               Среднее        False             средний
# 8636                Высшее        False       выше среднего
# 8674                Высшее        False             средний
# 8696                Высшее        False             средний
#
#           Дата.заполнения                                         User.Agent  \
# N
# 13    12/06/2017 13:05:54  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 69    12/06/2017 13:11:17  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 88    12/06/2017 13:12:25  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 115   12/06/2017 13:14:52  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 144   12/06/2017 13:19:10  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# ...                   ...                                                ...
# 8547  10/07/2017 14:11:26  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
# 8626  11/07/2017 16:15:40  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8636  11/07/2017 17:51:36  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 8674  12/07/2017 09:37:16  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....
# 8696  12/07/2017 14:39:21  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#        exp  current_job_exp  salary Язык.программирования
# N
# 13     1.0              0.0     800                Python
# 69     1.5              0.5     900                Python
# 88     0.5              0.5     600                Python
# 115    1.5              0.5     685                Python
# 144    1.0              1.0     750                Python
# ...    ...              ...     ...                   ...
# 8547   5.0              1.0    2000                Python
# 8626   4.0              1.0    1750                Python
# 8636  10.0              0.0    4000                Python
# 8674   0.5              0.5     350                Python
# 8696   1.0              0.5    1500                Python
#
# [207 rows x 19 columns]

# %% [markdown]
# Task10

# %%
print(f"кол-во столбцов :  {python_data.shape[1]}")
print(f"кол-во строк:  {python_data.shape[0]}")
# Out:
# кол-во столбцов :  20
# кол-во строк:  207

# %% [markdown]
# Task11

# %%
position = python_data.groupby(['Должность']).mean()
position
# Out:
#                           Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев  \
# Должность
# Junior Software Engineer        560.841270                        181.031746
# Senior Software Engineer       3387.096774                        431.612903
# Software Engineer              1799.070000                        479.830000
# System Architect               4000.000000                          0.000000
# Technical Lead                 3165.909091                        455.000000
#
#                             Возраст  Еще.студент        exp  current_job_exp  \
# Должность
# Junior Software Engineer  24.174603     0.380952   0.876984         0.523810
# Senior Software Engineer  29.064516     0.032258   6.677419         1.556452
# Software Engineer         26.630000     0.130000   3.180000         1.127500
# System Architect          35.500000     0.000000  10.000000         1.125000
# Technical Lead            30.090909     0.000000   7.090909         3.386364
#
#                                salary
# Должность
# Junior Software Engineer   560.841270
# Senior Software Engineer  3387.096774
# Software Engineer         1799.070000
# System Architect          4000.000000
# Technical Lead            3165.909091

# %% [markdown]
# Task12

# %%
position["Зарплата.в.месяц"].agg(['max', 'min'])
# Out:
# max    4000.00000
# min     560.84127
# Name: Зарплата.в.месяц, dtype: float64

# %% [markdown]
# Task13

# %%
def fill_avg_salary(data):
    avg_slr = data["Зарплата.в.месяц"].agg(['mean'])
    return avg_slr

position['avg'] = position.apply(lambda data: fill_avg_salary(position), axis=1)

position
# Out:
#                           Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев  \
# Должность
# Junior Software Engineer        560.841270                        181.031746
# Senior Software Engineer       3387.096774                        431.612903
# Software Engineer              1799.070000                        479.830000
# System Architect               4000.000000                          0.000000
# Technical Lead                 3165.909091                        455.000000
#
#                             Возраст  Еще.студент        exp  current_job_exp  \
# Должность
# Junior Software Engineer  24.174603     0.380952   0.876984         0.523810
# Senior Software Engineer  29.064516     0.032258   6.677419         1.556452
# Software Engineer         26.630000     0.130000   3.180000         1.127500
# System Architect          35.500000     0.000000  10.000000         1.125000
# Technical Lead            30.090909     0.000000   7.090909         3.386364
#
#                                salary          avg
# Должность
# Junior Software Engineer   560.841270  2582.583427
# Senior Software Engineer  3387.096774  2582.583427
# Software Engineer         1799.070000  2582.583427
# System Architect          4000.000000  2582.583427
# Technical Lead            3165.909091  2582.583427

# %% [markdown]
# Task14

# %%
position['avg'].describe()
# Out:
# count       5.000000
# mean     2582.583427
# std         0.000000
# min      2582.583427
# 25%      2582.583427
# 50%      2582.583427
# 75%      2582.583427
# max      2582.583427
# Name: avg, dtype: float64

# %% [markdown]
# Task15

# %%
position.to_csv("position.csv", index=True)
